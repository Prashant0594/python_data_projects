# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('C:/Users/prash/Desktop/python materials/python_data_projects/project_IPL_analysis/delivery.csv')
df_matches=pd.read_csv('C:/Users/prash/Desktop/python materials/python_data_projects/project_IPL_analysis/matches.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260920 entries, 0 to 260919
# Data columns (total 17 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   match_id          260920 non-null  int64
#  1   inning            260920 non-null  int64
#  2   batting_team      260920 non-null  object
#  3   bowling_team      260920 non-null  object
#  4   over              260920 non-null  int64
#  5   ball              260920 non-null  int64
#  6   batter            260920 non-null  object
#  7   bowler            260920 non-null  object
#  8   non_striker       260920 non-null  object
#  9   batsman_runs      260920 non-null  int64
#  10  extra_runs        260920 non-null  int64
#  11  total_runs        260920 non-null  int64
#  12  extras_type       14125 non-null   object
#  13  is_wicket         260920 non-null  int64
#  14  player_dismissed  12950 non-null   object
#  15  dismissal_kind    12950 non-null   object
#  16  fielder           9354 non-null    object
# dtypes: int64(8), object(9)
# memory usage: 33.8+ MB

# %%
df.sample(10)
# Out:
#         match_id  inning                 batting_team           bowling_team  \
# 126681    980935       2          Sunrisers Hyderabad        Kings XI Punjab
# 187388   1216526       1        Kolkata Knight Riders         Mumbai Indians
# 86789     598041       1          Chennai Super Kings        Kings XI Punjab
# 251366   1426269       2             Rajasthan Royals  Kolkata Knight Riders
# 225532   1312199       1  Royal Challengers Bangalore       Rajasthan Royals
# 181736   1216503       1               Mumbai Indians        Kings XI Punjab
# 121493    829815       2               Mumbai Indians    Sunrisers Hyderabad
# 152366   1136569       1               Mumbai Indians       Delhi Daredevils
# 11232     336031       2              Kings XI Punjab        Deccan Chargers
# 190032   1216537       1              Kings XI Punjab       Rajasthan Royals
#
#         over  ball         batter           bowler   non_striker  \
# 126681    11     6       S Dhawan   Sandeep Sharma    EJG Morgan
# 187388    12     1     PJ Cummins  NM Coulter-Nile    EJG Morgan
# 86789      2     6        WP Saha          P Kumar    MEK Hussey
# 251366    10     3     JC Buttler         CV Varun      R Ashwin
# 225532     7     6   F du Plessis         R Ashwin    RM Patidar
# 181736     5     6      RG Sharma        K Gowtham  Ishan Kishan
# 121493     9     5    LMP Simmons        KV Sharma      PA Patel
# 152366    12     5   Ishan Kishan        R Tewatia     RG Sharma
# 11232      7     2  KC Sangakkara        RG Sharma      SE Marsh
# 190032    12     3       KL Rahul        R Tewatia      CH Gayle
#
#         batsman_runs  extra_runs  total_runs extras_type  is_wicket  \
# 126681             1           0           1         NaN          0
# 187388             4           0           4         NaN          0
# 86789              0           0           0         NaN          0
# 251366             0           0           0         NaN          0
# 225532             0           0           0         NaN          0
# 181736             2           0           2         NaN          0
# 121493             0           0           0         NaN          0
# 152366             4           0           4         NaN          0
# 11232              0           1           1     legbyes          0
# 190032             1           0           1         NaN          0
#
#        player_dismissed dismissal_kind fielder
# 126681              NaN            NaN     NaN
# 187388              NaN            NaN     NaN
# 86789               NaN            NaN     NaN
# 251366              NaN            NaN     NaN
# 225532              NaN            NaN     NaN
# 181736              NaN            NaN     NaN
# 121493              NaN            NaN     NaN
# 152366              NaN            NaN     NaN
# 11232               NaN            NaN     NaN
# 190032              NaN            NaN     NaN

# %% [markdown]
# We'll work on following analysis:
#
# 1. Best Batsman
# - most runs
# - best average
# - best strike rate
# - best strike rate + average > 150 and total runs over 4000
# - batter with most 4s and 6s
#
# 2. Best Bowler
# - [WIP]

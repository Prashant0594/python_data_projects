# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

df1= pd.read_excel("C:/Users/prash/Desktop/data/online_retail_II.xlsx", sheet_name='Year 2009-2010')
df2= pd.read_excel('C:/Users/prash/Desktop/data/online_retail_II.xlsx', sheet_name='Year 2010-2011')

# %%
df1
# Out:
#        Invoice StockCode                          Description  Quantity  \
# 0       489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1       489434    79323P                   PINK CHERRY LIGHTS        12
# 2       489434    79323W                  WHITE CHERRY LIGHTS        12
# 3       489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4       489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...        ...       ...                                  ...       ...
# 525456  538171     22271                 FELTCRAFT DOLL ROSIE         2
# 525457  538171     22750         FELTCRAFT PRINCESS LOLA DOLL         1
# 525458  538171     22751       FELTCRAFT PRINCESS OLIVIA DOLL         1
# 525459  538171     20970   PINK FLORAL FELTCRAFT SHOULDER BAG         2
# 525460  538171     21931               JUMBO STORAGE BAG SUKI         2
#
#                InvoiceDate  Price  Customer ID         Country
# ...

# %%
df2
# Out:
#        Invoice StockCode                          Description  Quantity  \
# 0       536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1       536365     71053                  WHITE METAL LANTERN         6
# 2       536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3       536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4       536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...        ...       ...                                  ...       ...
# 541905  581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906  581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907  581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908  581587     22138        BAKING SET 9 PIECE RETROSPOT          3
# 541909  581587      POST                              POSTAGE         1
#
#                InvoiceDate  Price  Customer ID         Country
# ...

# %%
# Combine df1 and df2 into a single DataFrame
df = pd.concat([df1, df2], ignore_index=True)

# Display the combined DataFrame
df
# Out:
#         Invoice StockCode                          Description  Quantity  \
# 0        489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1        489434    79323P                   PINK CHERRY LIGHTS        12
# 2        489434    79323W                  WHITE CHERRY LIGHTS        12
# 3        489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4        489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...         ...       ...                                  ...       ...
# 1067366  581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 1067367  581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 1067368  581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 1067369  581587     22138        BAKING SET 9 PIECE RETROSPOT          3
# 1067370  581587      POST                              POSTAGE         1
#
#                 InvoiceDate  Price  Customer ID         Country
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1067371 entries, 0 to 1067370
# Data columns (total 8 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   Invoice      1067371 non-null  object
#  1   StockCode    1067371 non-null  object
#  2   Description  1062989 non-null  object
#  3   Quantity     1067371 non-null  int64
#  4   InvoiceDate  1067371 non-null  datetime64[ns]
#  5   Price        1067371 non-null  float64
#  6   Customer ID  824364 non-null   float64
#  7   Country      1067371 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 65.1+ MB

# %%
df['StockCode'].value_counts()
# Out:
# StockCode
# 85123A    5829
# 22423     4424
# 85099B    4216
# 21212     3318
# 20725     3259
#           ...
# 23609        1
# 23617        1
# 21835        1
# 47594a       1
# 84867a       1
# Name: count, Length: 5305, dtype: int64

# %%
df[df['Description'].isnull()]['StockCode'].unique()
# Out:
# array([21646, 20683, 21350, ..., 23406, 21620, 85175],
#       shape=(2451,), dtype=object)

# %%
# Assuming 'InvoiceDate' is the datetime column in your DataFrame
df['Year'] = df['InvoiceDate'].dt.year
df['Month'] = df['InvoiceDate'].dt.month
df['Day'] = df['InvoiceDate'].dt.day

# Display the updated DataFrame
df.head()
# Out:
#   Invoice StockCode                          Description  Quantity  \
# 0  489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1  489434    79323P                   PINK CHERRY LIGHTS        12
# 2  489434    79323W                  WHITE CHERRY LIGHTS        12
# 3  489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4  489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
#
#           InvoiceDate  Price  Customer ID         Country  Year  Month  Day
# 0 2009-12-01 07:45:00   6.95      13085.0  United Kingdom  2009     12    1
# 1 2009-12-01 07:45:00   6.75      13085.0  United Kingdom  2009     12    1
# 2 2009-12-01 07:45:00   6.75      13085.0  United Kingdom  2009     12    1
# 3 2009-12-01 07:45:00   2.10      13085.0  United Kingdom  2009     12    1
# 4 2009-12-01 07:45:00   1.25      13085.0  United Kingdom  2009     12    1

# %%
df.groupby('Description')['Quantity'].sum().sort_values(ascending=False).head(10)
# Out:
# Description
# WORLD WAR 2 GLIDERS ASSTD DESIGNS     108545
# WHITE HANGING HEART T-LIGHT HOLDER     93050
# ASSORTED COLOUR BIRD ORNAMENT          81306
# JUMBO BAG RED RETROSPOT                78090
# BROCADE RING PURSE                     70700
# PACK OF 60 PINK PAISLEY CAKE CASES     56575
# 60 TEATIME FAIRY CAKE CASES            54366
# SMALL POPCORN HOLDER                   49616
# PACK OF 72 RETROSPOT CAKE CASES        49344
# PACK OF 72 RETRO SPOT CAKE CASES       46106
# Name: Quantity, dtype: int64

# %%
df['Description'].value_counts().head(10)
# Out:
# Description
# WHITE HANGING HEART T-LIGHT HOLDER    5918
# REGENCY CAKESTAND 3 TIER              4412
# JUMBO BAG RED RETROSPOT               3469
# ASSORTED COLOUR BIRD ORNAMENT         2958
# PARTY BUNTING                         2765
# STRAWBERRY CERAMIC TRINKET BOX        2613
# LUNCH BAG  BLACK SKULL.               2529
# JUMBO STORAGE BAG SUKI                2434
# HEART OF WICKER SMALL                 2319
# JUMBO SHOPPER VINTAGE RED PAISLEY     2297
# Name: count, dtype: int64

# %%
# Assuming 'InvoiceDate' is the datetime column in your DataFrame
df['Quarter'] = df['InvoiceDate'].dt.quarter

# Display the updated DataFrame
df.head()
# Out:
#   Invoice StockCode                          Description  Quantity  \
# 0  489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1  489434    79323P                   PINK CHERRY LIGHTS        12
# 2  489434    79323W                  WHITE CHERRY LIGHTS        12
# 3  489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4  489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
#
#           InvoiceDate  Price  Customer ID         Country  Year  Month  Day  \
# 0 2009-12-01 07:45:00   6.95      13085.0  United Kingdom  2009     12    1
# 1 2009-12-01 07:45:00   6.75      13085.0  United Kingdom  2009     12    1
# 2 2009-12-01 07:45:00   6.75      13085.0  United Kingdom  2009     12    1
# 3 2009-12-01 07:45:00   2.10      13085.0  United Kingdom  2009     12    1
# 4 2009-12-01 07:45:00   1.25      13085.0  United Kingdom  2009     12    1
#
#    Quarter
# 0        4
# 1        4
# 2        4
# 3        4
# 4        4

# %%
# Assuming 'Month' is the column with month numbers
df['MonthName'] = pd.to_datetime(df['Month'], format='%m').dt.month_name()

# Display the updated DataFrame
df.head()
# Out:
#   Invoice StockCode                          Description  Quantity  \
# 0  489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1  489434    79323P                   PINK CHERRY LIGHTS        12
# 2  489434    79323W                  WHITE CHERRY LIGHTS        12
# 3  489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4  489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
#
#           InvoiceDate  Price  Customer ID         Country  Year  Month  Day  \
# 0 2009-12-01 07:45:00   6.95      13085.0  United Kingdom  2009     12    1
# 1 2009-12-01 07:45:00   6.75      13085.0  United Kingdom  2009     12    1
# 2 2009-12-01 07:45:00   6.75      13085.0  United Kingdom  2009     12    1
# 3 2009-12-01 07:45:00   2.10      13085.0  United Kingdom  2009     12    1
# 4 2009-12-01 07:45:00   1.25      13085.0  United Kingdom  2009     12    1
#
#    Quarter MonthName
# 0        4  December
# 1        4  December
# 2        4  December
# ...

# %%
df['sales'] = df['Quantity'] * df['Price']
df.sample(10)
# Out:
#         Invoice StockCode                          Description  Quantity  \
# 665675   548386     23003     TRAVEL CARD WALLET VINTAGE ROSE          1
# 674609   549279     22505            MEMO BOARD COTTAGE DESIGN         1
# 668615   548666     22372  AIRLINE BAG VINTAGE WORLD CHAMPION          2
# 807833   561645     22952      60 CAKE CASES VINTAGE CHRISTMAS       240
# 359228   524199     22719         GUMBALL MONOCHROME COAT RACK         1
# 173335   505809     21865     PINK UNION JACK  PASSPORT COVER          2
# 1017405  578081     23355           HOT WATER BOTTLE KEEP CALM        24
# 629587   545150     22920                    HERB MARKER BASIL        12
# 767970   558355     23298                       SPOTTY BUNTING         4
# 1018282  578149     22179              SET 10 NIGHT OWL LIGHTS         2
#
#                 InvoiceDate  Price  Customer ID         Country  Year  Month  \
# 665675  2011-03-30 16:48:00   0.42          NaN  United Kingdom  2011      3
# ...

# %%
df2010sales=df[df['Year']==2010].groupby(['Month','MonthName']).agg({'sales':'sum'})
df2010sales
# Out:
#                        sales
# Month MonthName
# 1     January     624032.892
# 2     February    533091.426
# 3     March       765848.761
# 4     April       590580.432
# 5     May         615322.830
# 6     June        679786.610
# 7     July        575236.360
# 8     August      656776.340
# 9     September   853650.431
# 10    October    1045168.350
# 11    November   1422654.642
# 12    December   1126445.470

# %%
df2010sales.reset_index(inplace=True)
df2010sales
# Out:
#     Month  MonthName        sales
# 0       1    January   624032.892
# 1       2   February   533091.426
# 2       3      March   765848.761
# 3       4      April   590580.432
# 4       5        May   615322.830
# 5       6       June   679786.610
# 6       7       July   575236.360
# 7       8     August   656776.340
# 8       9  September   853650.431
# 9      10    October  1045168.350
# 10     11   November  1422654.642
# 11     12   December  1126445.470

# %%
df2010sales.drop(columns='Month', inplace=True)
df2010sales
# Out:
#     MonthName        sales
# 0     January   624032.892
# 1    February   533091.426
# 2       March   765848.761
# 3       April   590580.432
# 4         May   615322.830
# 5        June   679786.610
# 6        July   575236.360
# 7      August   656776.340
# 8   September   853650.431
# 9     October  1045168.350
# 10   November  1422654.642
# 11   December  1126445.470

# %%
sns.barplot(x='MonthName', y='sales', data=df2010sales, palette='viridis',hue='MonthName')
plt.title('Monthly Sales in 2010')
plt.xlabel('')
plt.ylabel('Sales')
sns.despine()
plt.tight_layout()
plt.xticks(rotation=90)
plt.show()

# %%
df2011sales=df[df['Year']==2011].groupby(['Month','MonthName']).agg({'sales':'sum'})
df2011sales
# Out:
#                        sales
# Month MonthName
# 1     January     560000.260
# 2     February    498062.650
# 3     March       683267.080
# 4     April       493207.121
# 5     May         723333.510
# 6     June        691123.120
# 7     July        681300.111
# 8     August      682680.510
# 9     September  1019687.622
# 10    October    1070704.670
# 11    November   1461756.250
# 12    December    433686.010

# %%
df2011sales.reset_index(inplace=True)
df2011sales
# Out:
#     Month  MonthName        sales
# 0       1    January   560000.260
# 1       2   February   498062.650
# 2       3      March   683267.080
# 3       4      April   493207.121
# 4       5        May   723333.510
# 5       6       June   691123.120
# 6       7       July   681300.111
# 7       8     August   682680.510
# 8       9  September  1019687.622
# 9      10    October  1070704.670
# 10     11   November  1461756.250
# 11     12   December   433686.010

# %%
df2011sales.drop(columns='Month', inplace=True)
df2011sales
# Out:
#     MonthName        sales
# 0     January   560000.260
# 1    February   498062.650
# 2       March   683267.080
# 3       April   493207.121
# 4         May   723333.510
# 5        June   691123.120
# 6        July   681300.111
# 7      August   682680.510
# 8   September  1019687.622
# 9     October  1070704.670
# 10   November  1461756.250
# 11   December   433686.010

# %%
sns.barplot(x='MonthName', y='sales', data=df2011sales, palette='viridis',hue='MonthName')
plt.title('Monthly Sales in 2011')
plt.xlabel('')
plt.ylabel('Sales')
sns.despine()
plt.tight_layout()
plt.xticks(rotation=90)
plt.show()

# %%
# Assuming df2010sales and df2011sales are already prepared
# Merge the two DataFrames on 'MonthName' for comparison
comparison_df = pd.merge(df2010sales, df2011sales, on='MonthName', suffixes=('_2010', '_2011'))

# Plot the barplot for 2010 sales
sns.barplot(x='MonthName', y='sales_2010', data=comparison_df, color='skyblue', label='2010 Sales')

# Add a line plot for 2011 sales
plt.plot(comparison_df['MonthName'], comparison_df['sales_2011'], color='red', marker='o', label='2011 Sales')

# Add labels, title, and legend
plt.title('Month-on-Month Sales Comparison (2010 vs 2011)')
plt.xlabel('Month')
plt.ylabel('Sales')
plt.xticks(rotation=90)
plt.legend()
sns.despine()
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# CONCLUSION: Looking at 2010 and 2011 monthly sales data, i can infer that in the last quarter the sales are their peak.
# probable reasons- festivals and holidays
# There is an anomoly in 2011 December sales data- either the data is not captured or some data is missing.
